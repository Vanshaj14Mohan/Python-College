# %%
import pandas as pd
import  numpy as npt 
import seaborn as sns

# %%
#For Line Chart
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [15, 25, 17, 24, 35]
plt.plot(x, y)
plt.title("Line chart")
plt.show()

# %%
#For Bar Chart
plt.bar(["A", "B", "C","D"], [10,20,30, 40])
plt.title("Bar chart")
plt.show()

# %%
#For Pie Chart
labels = ["A", "B", "C"]
sizes = [25,35,40]
plt.pie(sizes, labels = labels)
plt.title("Pie chart")
plt.show()

# %%
#For Scatter Plot
x= [1,2,3,4,5,6,7]
y = [10,20,30,40,45,48,50]
plt.scatter(x,y)
plt.title("Scatter Plot")
plt.show()

# %%
import numpy as np
#using numpy to print the standard deviation of an array
arr = [1, 2, 3, 4, 5]
print(np.std(arr))
# Out:
# 1.4142135623730951

# %%
#1 WAP to Compare Two Arrays for Equality
# Test case 1: Equal arrays
def compare_arrays(arr1, arr2):
    if len(arr1) != len(arr2):
        return False
    for i in range(len(arr1)):
        if arr1[i] != arr2[i]:
            return False
    return True
arr1 = [1, 2, 3, 4, 5]
arr2 = [1, 2, 3, 4, 5]
print(compare_arrays(arr1, arr2))  #True

# Test case 2: Unequal arrays
arr1 = [1, 2, 3, 4, 5]
arr2 = [1, 2, 3, 4, 6]
print(compare_arrays(arr1, arr2))  #False
# Out:
# True
# False
