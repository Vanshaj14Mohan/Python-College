# %%
import numpy as np
import pandas as pd

# %%
#LINE GRAPH
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [10,25,20,40,30]
plt.plot(x,y)
plt.title("Normal graph")
plt.show()

# %%
plt.bar(["A", "B", "C"],[10,20,30])
plt.title("Bar graph")
plt.show()
